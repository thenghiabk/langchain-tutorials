# %% [markdown]
# # Google Gemini

# %%
import os
import google.generativeai as genai
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Configure the API key
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))

# %%
# Initialize the model
model = genai.GenerativeModel('gemini-2.5-flash')

# %%
PROMPT = """
Hello, Gemini!
"""

# %%
# Make your first API call
response = model.generate_content(
    contents=PROMPT,
    generation_config=genai.GenerationConfig(
        temperature=0.7,    # control randomness in responses
                            # 0-0.3: Factual, consistent responses
                            # 0.4-0.7: Balanced creativity
                            # 0.8-1.0: Creative, varied responses
        top_p=0.1,  # considers tokens with top cumulative probability mass
                    # 0.1: Very focused, predictable
                    # 0.5: Moderately diverse
                    # 1.0: Consider all options
    )
)
# Print the response
print(response.text)

# %% [markdown]
# # Open Source Models with Ollama

# %%
import requests
import json

response = requests.post(
    "http://localhost:11434/api/generate", # 11434 : default port
    json={
        "model": "gemma:2b",
        "prompt": "Hello, Llama!",
        "stream": False
    }
)

print(json.loads(response.text)["response"])

# %% [markdown]
# # Unified Interface with LangChain

# %%
from langchain_openai import ChatOpenAI
from langchain_anthropic import ChatAnthropic
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_ollama import OllamaLLM

# %%
# Initialize different models
# gpt4 = ChatOpenAI(model="gpt-4", temperature=0.7)
# claude = ChatAnthropic(model="claude-3-opus-20240229")
gemini = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
llama = Ollama(model="gemma:2b")

# %%
# Use the same interface for all
prompt = "Explain quantum computing in simple terms"

# %%
# Each model uses the same method
# gpt_response = gpt4.invoke(prompt)
# claude_response = claude.invoke(prompt)
gemini_response = gemini.invoke(prompt)
# llama_response = llama.invoke(prompt)

# %%
print(gemini_response.content)
# Out:
# Imagine a regular computer as a light switch that can be either **ON** or **OFF**. This is how it stores information: as a **bit**, which is either a **0** or a **1**.
#
# Now, imagine a quantum computer. Instead of a simple light switch, think of it like a **spinning coin**.
#
# Here's the breakdown:
#
# 1.  **Qubits (Quantum Bits): More Than Just On/Off**
#     *   A regular computer uses **bits** (0 or 1).
#     *   A quantum computer uses **qubits**. A qubit isn't just 0 or 1. Thanks to quantum mechanics, it can be **0**, **1**, or **both 0 and 1 at the same time**!
#     *   Think of our spinning coin: while it's spinning in the air, it's neither heads nor tails, but a combination of both. Only when it lands does it become definitively heads (0) or tails (1). This "both at once" state is called **superposition**.
#
# 2.  **Superposition: Doing Many Things at Once**
#     *   Because a qubit can be 0 and 1 simultaneously, a quantum computer with multiple qubits can explore a vast number of possibilities *at the same time*.
#     *   Instead of trying one solution after another (like a classical computer), it can effectively try many solutions in parallel, massively speeding up certain types of calculations.
#
# 3.  **Entanglement: Spooky Connections**
#     *   This is where it gets really weird. **Entanglement** means that two or more qubits can become linked in such a way that they share the same fate, no matter how far apart they are.
#     *   If you measure one entangled qubit, you instantly know the state of the other, even without looking at it.
#     *   Imagine two spinning coins that are magically linked: if one lands heads, the other *must* land tails.
#     *   This allows qubits to work together in incredibly complex ways, creating powerful computational shortcuts that are impossible for classical computers.
#
# **So, how does it work in simple terms?**
#
# A quantum computer uses the bizarre rules of the universe (superposition and entanglement) to create a fundamentally different kind of computer.
#
# *   Instead of dealing with information one bit at a time, it can process many possibilities simultaneously (thanks to superposition).
# *   And instead of just individual calculations, it can link these calculations in a "spooky" way (thanks to entanglement) to find solutions to problems that are too complex for even the most powerful supercomputers today.
#
# **What is it good for?**
#
# It's not just a faster version of your laptop. It's good for specific, extremely complex problems like:
#
# *   **Drug Discovery:** Simulating molecules to find new medicines.
# *   **Material Science:** Designing new materials with specific properties.
# *   **Cryptography:** Breaking or creating highly secure codes.
# *   **Optimization:** Finding the best solution among countless possibilities (e.g., logistics, financial modeling).
# *   **Artificial Intelligence:** Enhancing machine learning algorithms.
#
# **In essence:** Quantum computing taps into the weirdness of the subatomic world to solve problems that are currently beyond our reach. It's still in its early stages, but it holds immense potential to revolutionize many fields.

# %%
print(llama_response)
# Out:
# Sure, here's a simple explanation of quantum computing:
#
# **Imagine a regular computer like a light switch.** It can be either on or off, representing 1 or 0.
#
# **A quantum computer is like a dimmer switch.** It can be on, off, or anywhere in between. This is because it uses **qubits**, which are like super-powered bits that can be both 1 and 0 at the same time.
#
# **Qubits are like a special kind of particle that can travel in multiple directions at once.** This is called **superposition**.
#
# **This ability allows quantum computers to explore many possibilities simultaneously,** which helps them solve problems that would take a regular computer an eternity to solve.
#
# **Here's an analogy:**
#
# * Think of a maze. A regular computer would explore each path one by one until it found the exit.
# * A quantum computer could explore all the paths at once, making it much faster to find the exit.
#
# **Quantum computing is still early in development,** but it has the potential to do amazing things, such as:
#
# * Developing new drugs
# * Breaking encryption
# * Creating new materials
# * Solving complex problems in finance and medicine
#
# **It's important to note that quantum computing is not a replacement for regular computers.** It's more of a tool that can be used to solve specific problems that are too difficult for regular computers.
#
# I hope this explanation helps! Let me know if you have any other questions.
